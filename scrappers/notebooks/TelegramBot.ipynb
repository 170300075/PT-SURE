# %%
# read the environmental variables file
readRenviron("../../.env")
token <- Sys.getenv('TELEGRAM_TOKEN')

# %%
library(telegram.bot)

# %%
bot <- Bot(token = token)

# %%
chat_id <- "1564446434"

# %%
bot$sendMessage(chat_id = chat_id, text = "Hola Kenneth, soy un bot de Telegram")
